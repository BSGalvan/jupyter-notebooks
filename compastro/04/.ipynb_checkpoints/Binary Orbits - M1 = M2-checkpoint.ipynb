# %%
# Imports and Magics required for plotting animations

# %matplotlib nbagg 
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

# Setup the figure
fig = plt.figure()
fig.set_dpi(100)
fig.set_size_inches(7, 6.5)
ax = plt.axes(xlim=(0, 10), ylim=(0, 10))

# Create objects to be plotted
patch1 = plt.Circle((5, -5), 0.1, fc='r')
patch2 = plt.Circle((5, -5), 0.1, fc='r')

# Create and add into the figure, objects which will NOT be redrawn every frame
path = plt.Circle((5, 5), 3, fill=False, fc='k')
vertLine = plt.Line2D((5, 5), (4.6, 5.4), c='g')
horLine = plt.Line2D((4.6, 5.4), (5, 5), c='g')
ax.add_patch(path)
ax.add_artist(vertLine)
ax.add_artist(horLine)

# Initialisation function
def init():
    patch1.center = (5, 5)
    patch2.center = (5, 5)
    ax.add_patch(patch1)
    ax.add_patch(patch2)
    return patch1, patch2, 

# Animator function
def animate(i):
    x1, y1 = patch1.center
    x2, y2 = patch2.center
    x1 = 5 + 3 * np.sin(np.radians(i))
    y1 = 5 + 3 * np.cos(np.radians(i))
    x2 = 5 + 3 * np.sin(np.radians(i) - np.pi)
    y2 = 5 + 3 * np.cos(np.radians(i) - np.pi)
    patch1.center = (x1, y1)
    patch2.center = (x2, y2)
    return patch1, patch2, 

# Call the animator
anim = animation.FuncAnimation(fig, animate, 
                               init_func=init, 
                               frames=360, 
                               interval=10,
                               blit=True)

# Show the animation
#ax.axis(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
help(animation.FuncAnimation)
# Out:
# Help on class FuncAnimation in module matplotlib.animation:
#
# class FuncAnimation(TimedAnimation)
#  |  FuncAnimation(fig, func, frames=None, init_func=None, fargs=None, save_count=None, *, cache_frame_data=True, **kwargs)
#  |
#  |  Makes an animation by repeatedly calling a function *func*.
#  |
#  |  Parameters
#  |  ----------
#  |  fig : matplotlib.figure.Figure
#  |     The figure object that is used to get draw, resize, and any
#  |     other needed events.
#  |
#  |  func : callable
#  |     The function to call at each frame.  The first argument will
#  |     be the next value in *frames*.   Any additional positional
#  |     arguments can be supplied via the *fargs* parameter.
#  |
#  |     The required signature is::
#  |
#  |        def func(frame, *fargs) -> iterable_of_artists
#  |
#  |     If ``blit == True``, *func* must return an iterable of all artists
#  |     that were modified or created. This information is used by the blitting
# ...
